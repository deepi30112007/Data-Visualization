# %%
import numpy as np

# %%
arr=np.array([4,5,6,7,8,9])
print(arr.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 arr=np.array([4,5,6,7,8,9])
#       2 print(arr.shape)
#
# NameError: name 'np' is not defined

# %%
arr=np.array([4,5,6,7,8,9])
print(arr.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 arr=np.array([4,5,6,7,8,9])
#       2 print(arr.shape)
#
# NameError: name 'np' is not defined
